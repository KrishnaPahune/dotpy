# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bank.csv')
df
# Out:
#           id  age          job  marital  education default  balance housing  \
# 0          1   59       admin.  married  secondary      no     2343     yes
# 1          2   56       admin.  married  secondary      no       45      no
# 2          3   41   technician  married  secondary      no     1270     yes
# 3          4   55     services  married  secondary      no     2476     yes
# 4          5   54       admin.  married   tertiary      no      184      no
# ...      ...  ...          ...      ...        ...     ...      ...     ...
# 11157  11158   33  blue-collar   single    primary      no        1     yes
# 11158  11159   39     services  married  secondary      no      733      no
# 11159  11160   32   technician   single  secondary      no       29      no
# 11160  11161   43   technician  married  secondary      no        0      no
# 11161  11162   34   technician  married  secondary      no        0      no
#
# ...

# %%
df.shape
# Out:
# (11162, 18)

# %%
df.dtypes
# Out:
# id            int64
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df.head()
# Out:
#    id  age         job  marital  education default  balance housing loan  \
# 0   1   59      admin.  married  secondary      no     2343     yes   no
# 1   2   56      admin.  married  secondary      no       45      no   no
# 2   3   41  technician  married  secondary      no     1270     yes   no
# 3   4   55    services  married  secondary      no     2476     yes   no
# 4   5   54      admin.  married   tertiary      no      184      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# 1  unknown    5   may      1467         1     -1         0  unknown     yes
# 2  unknown    5   may      1389         1     -1         0  unknown     yes
# 3  unknown    5   may       579         1     -1         0  unknown     yes
# 4  unknown    5   may       673         2     -1         0  unknown     yes

# %%
df.tail()
# Out:
#           id  age          job  marital  education default  balance housing  \
# 11157  11158   33  blue-collar   single    primary      no        1     yes
# 11158  11159   39     services  married  secondary      no      733      no
# 11159  11160   32   technician   single  secondary      no       29      no
# 11160  11161   43   technician  married  secondary      no        0      no
# 11161  11162   34   technician  married  secondary      no        0      no
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157   no  cellular   20   apr       257         1     -1         0  unknown
# 11158   no   unknown   16   jun        83         4     -1         0  unknown
# 11159   no  cellular   19   aug       156         2     -1         0  unknown
# 11160  yes  cellular    8   may         9         2    172         5  failure
# 11161   no  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# ...

# %%
df.head(10)
# Out:
#    id  age         job   marital  education default  balance housing loan  \
# 0   1   59      admin.   married  secondary      no     2343     yes   no
# 1   2   56      admin.   married  secondary      no       45      no   no
# 2   3   41  technician   married  secondary      no     1270     yes   no
# 3   4   55    services   married  secondary      no     2476     yes   no
# 4   5   54      admin.   married   tertiary      no      184      no   no
# 5   6   42  management    single   tertiary      no        0     yes  yes
# 6   7   56  management   married   tertiary      no      830     yes  yes
# 7   8   60     retired  divorced  secondary      no      545     yes   no
# 8   9   37  technician   married  secondary      no        1     yes   no
# 9  10   28    services    single  secondary      no     5090     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# ...

# %% [markdown]
# # Missing Values

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         11162 non-null  int64
#  1   age        11162 non-null  int64
#  2   job        11162 non-null  object
#  3   marital    11162 non-null  object
#  4   education  11162 non-null  object
#  5   default    11162 non-null  object
#  6   balance    11162 non-null  int64
#  7   housing    11162 non-null  object
#  8   loan       11162 non-null  object
#  9   contact    11162 non-null  object
#  10  day        11162 non-null  int64
#  11  month      11162 non-null  object
#  12  duration   11162 non-null  int64
#  13  campaign   11162 non-null  int64
#  14  pdays      11162 non-null  int64
#  15  previous   11162 non-null  int64
#  16  poutcome   11162 non-null  object
#  17  deposit    11162 non-null  object
# dtypes: int64(8), object(10)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#                  id           age       balance           day      duration  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean    5581.500000     41.231948   1528.538524     15.658036    371.993818
# std     3222.336187     11.913369   3225.413326      8.420740    347.128386
# min        1.000000     18.000000  -6847.000000      1.000000      2.000000
# 25%     2791.250000     32.000000    122.000000      8.000000    138.000000
# 50%     5581.500000     39.000000    550.000000     15.000000    255.000000
# 75%     8371.750000     49.000000   1708.000000     22.000000    496.000000
# max    11162.000000     95.000000  81204.000000     31.000000   3881.000000
#
#            campaign         pdays      previous
# count  11162.000000  11162.000000  11162.000000
# mean       2.508421     51.330407      0.832557
# std        2.722077    108.758282      2.292007
# min        1.000000     -1.000000      0.000000
# ...

# %%
columns = df.columns

# %%
df[columns[0]].mean()
# Out:
# np.float64(5581.5)

# %% [markdown]
# ## Selecting Features

# %%
selected_features=df[['age','balance','day','duration']]
selected_features
# Out:
#        age  balance  day  duration
# 0       59     2343    5      1042
# 1       56       45    5      1467
# 2       41     1270    5      1389
# 3       55     2476    5       579
# 4       54      184    5       673
# ...    ...      ...  ...       ...
# 11157   33        1   20       257
# 11158   39      733   16        83
# 11159   32       29   19       156
# 11160   43        0    8         9
# 11161   34        0    9       628
#
# [11162 rows x 4 columns]

# %%
columns=selected_features.columns
columns
# Out:
# Index(['age', 'balance', 'day', 'duration'], dtype='object')

# %% [markdown]
# ## Printing Mean,Max,Std,Min and Count
# this function is used to print the mean, max, min, standard deviation and count of the selected features. It uses for loop

# %%
def info():
    for i in range(0,4):
        print(f"The mean of {columns[i]} is {df[columns[i]].mean()}")
        print(f"The count of {columns[i]} is {df[columns[i]].count()}")
        print(f"The stanard deviation of {columns[i]} is {df[columns[i]].std()}")
        print(f"The minimum of {columns[i]} is {df[columns[i]].min()}")
        print(f"The maximum of {columns[i]} is {df[columns[i]].max()}")
        print("-".center(50,"-"))

# %%
info()
# Out:
# The mean of age is 41.231947679627304
# The count of age is 11162
# The stanard deviation of age is 11.913369192215526
# The minimum of age is 18
# The maximum of age is 95
# --------------------------------------------------
# The mean of balance is 1528.5385235620856
# The count of balance is 11162
# The stanard deviation of balance is 3225.413325946151
# The minimum of balance is -6847
# The maximum of balance is 81204
# --------------------------------------------------
# The mean of day is 15.658036194230425
# The count of day is 11162
# The stanard deviation of day is 8.420739541006451
# The minimum of day is 1
# The maximum of day is 31
# --------------------------------------------------
# The mean of duration is 371.99381831213043
# The count of duration is 11162
# The stanard deviation of duration is 347.12838571630584
# The minimum of duration is 2
# The maximum of duration is 3881
# --------------------------------------------------

# %%
duplicate_values = df.duplicated().sum()
duplicate_values
# Out:
# np.int64(0)

# %%
x = df['age']
x
# Out:
# 0        59
# 1        56
# 2        41
# 3        55
# 4        54
#          ..
# 11157    33
# 11158    39
# 11159    32
# 11160    43
# 11161    34
# Name: age, Length: 11162, dtype: int64

# %%
y = df['balance']
y
# Out:
# 0        2343
# 1          45
# 2        1270
# 3        2476
# 4         184
#          ...
# 11157       1
# 11158     733
# 11159      29
# 11160       0
# 11161       0
# Name: balance, Length: 11162, dtype: int64

# %% [markdown]
# <h2>Scatter plot</h2>

# %%
plt.scatter(x,y)
plt.xlabel="Age"
plt.ylabel="Balance"
plt.legend()
plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_15596\2980298872.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# <h2>Bar Graph</h2>

# %%
plt.bar(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (8929,)

# %%
x_test.shape
# Out:
# (2233,)

# %%
y_train.shape
# Out:
# (8929,)

# %%
y_test.shape
# Out:
# (2233,)

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size
# Out:
# 10692

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
null_counts=df.isnull().sum()
null_counts
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.dropna()

# %%
null_counts=df.isnull().sum()
null_counts
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
duplicates=df.duplicated().sum()
duplicates
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
print(f"Shape of X_train data is {x_train.shape}")
print(f"Shape of y_train data is {y_train.shape}")
print(f"Shape of X_test data is {x_test.shape}")
print(f"Shape of y_test data is {y_test.shape}")
# Out:
# Shape of X_train data is (8929,)
# Shape of y_train data is (8929,)
# Shape of X_test data is (2233,)
# Shape of y_test data is (2233,)
